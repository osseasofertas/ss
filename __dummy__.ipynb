# %% [markdown]
# Atualizando o ID e os assets da VSL Converteai para o novo player informado.

# %% [markdown]
# Substituir player.js antigo e m3u8 antigo pelas novas URLs passadas pelo usuário.

# %% [markdown]
# Atualizar também o id usado no componente SmartPlayer para `vid-692d4694d69941550924da09`.

# %%
dummy
